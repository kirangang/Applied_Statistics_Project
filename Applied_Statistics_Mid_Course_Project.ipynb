# %% [markdown]
# <a href="https://colab.research.google.com/github/kirangang/Applied_Statistics_Project/blob/main/Applied_Statistics_Mid_Course_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %% [markdown]
# ### Import Libraries

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Connecting the google colab notebook with the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv("/content/drive/MyDrive/Superstore Marketing Data.csv")

# %%
# Shows first 5 rows
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
# Shows last 5 rows
df.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    ########       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0    ########       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    ########       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
# Dataset Rows and Columns Count
shape_of_df = df.shape
print("Number of Rows:", shape_of_df[0])
print("Number of Columns:", shape_of_df[1])
# Out:
# Number of Rows: 2240
# Number of Columns: 22

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Displaying dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# Dataset Describe
df.describe(include="all").T
# Out:
#                       count unique         top  freq          mean  \
# Id                   2240.0    NaN         NaN   NaN   5592.159821
# Year_Birth           2240.0    NaN         NaN   NaN   1968.805804
# Education              2240      5  Graduation  1127           NaN
# Marital_Status         2240      8     Married   864           NaN
# Income               2216.0    NaN         NaN   NaN  52247.251354
# Kidhome              2240.0    NaN         NaN   NaN      0.444196
# Teenhome             2240.0    NaN         NaN   NaN       0.50625
# Dt_Customer            2240    401    ########   916           NaN
# Recency              2240.0    NaN         NaN   NaN     49.109375
# MntWines             2240.0    NaN         NaN   NaN    303.935714
# MntFruits            2240.0    NaN         NaN   NaN     26.302232
# MntMeatProducts      2240.0    NaN         NaN   NaN        166.95
# MntFishProducts      2240.0    NaN         NaN   NaN     37.525446
# ...

# %%
# Creating a copy of our dataset
data = df.copy()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_rows = len(data[data.duplicated()])
print("Number of duplicate rows:", duplicate_rows)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# Here we can see there are no duplicate values.

# %% [markdown]
# #### Missing Values/Null Values

# %% [markdown]
# * This dataset contains special characters like "########" in the Dt_Customer column, so we will replace them with null values and remove them from our dataset.

# %%
# Replacing "########" with NaN in the "Dt_Customer" column
data['Dt_Customer'] = data['Dt_Customer'].replace('########', pd.NA)

# %%
# Drop rows with missing values in the "Dt_Customer" column
data = data.dropna(subset=['Dt_Customer'])

# %%
# Missing Values/Null Values Count
column_with_nan = data.isnull().sum().sort_values(ascending=False)
print(column_with_nan)
# Out:
# Income                 13
# Id                      0
# MntFishProducts         0
# Response                0
# NumWebVisitsMonth       0
# NumStorePurchases       0
# NumCatalogPurchases     0
# NumWebPurchases         0
# NumDealsPurchases       0
# MntGoldProds            0
# MntSweetProducts        0
# MntMeatProducts         0
# Year_Birth              0
# MntFruits               0
# MntWines                0
# Recency                 0
# Dt_Customer             0
# Teenhome                0
# Kidhome                 0
# Marital_Status          0
# Education               0
# Complain                0
# dtype: int64

# %% [markdown]
# Here Income column has only 13 null values, so we will drop those rows from our dataset.

# %%
# Drop rows with missing values in the "Income" column
data = data.dropna(subset=['Income'])

# %%
# Checking if the dataset contain any null values
data.isnull().sum().sort_values(ascending=False)
# Out:
# Id                     0
# Year_Birth             0
# Response               0
# NumWebVisitsMonth      0
# NumStorePurchases      0
# NumCatalogPurchases    0
# NumWebPurchases        0
# NumDealsPurchases      0
# MntGoldProds           0
# MntSweetProducts       0
# MntFishProducts        0
# MntMeatProducts        0
# MntFruits              0
# MntWines               0
# Recency                0
# Dt_Customer            0
# Teenhome               0
# Kidhome                0
# Income                 0
# Marital_Status         0
# Education              0
# Complain               0
# dtype: int64

# %% [markdown]
# Now, the dataset does not contain any missing values.

# %% [markdown]
# # Changing data type of column

# %% [markdown]
# The data type of Dt_Customer column is string so we will convert its data type to datetime.

# %%
data['Dt_Customer'] = pd.to_datetime(data['Dt_Customer'], format='%m/%d/%Y', errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1311 entries, 0 to 2238
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1311 non-null   int64
#  1   Year_Birth           1311 non-null   int64
#  2   Education            1311 non-null   object
#  3   Marital_Status       1311 non-null   object
#  4   Income               1311 non-null   float64
#  5   Kidhome              1311 non-null   int64
#  6   Teenhome             1311 non-null   int64
#  7   Dt_Customer          1311 non-null   datetime64[ns]
#  8   Recency              1311 non-null   int64
#  9   MntWines             1311 non-null   int64
#  10  MntFruits            1311 non-null   int64
#  11  MntMeatProducts      1311 non-null   int64
#  12  MntFishProducts      1311 non-null   int64
#  13  MntSweetProducts     1311 non-null   int64
#  14  MntGoldProds         1311 non-null   int64
# ...

# %% [markdown]
# # Adding new column

# %% [markdown]
# We will add Age column by substracting Year_Birth column from Dt_Customer column, so that we will be able to analyze its distribution.

# %%
# Converting the data type of 'Year_Birth' column to datetime to calculate 'Age'
data['Year_Birth'] = pd.to_datetime(data['Year_Birth'], format='%Y')

# Calculating the age of customers by taking the difference between their year of birth and enrollment
data['Age'] = (data['Dt_Customer'] - data['Year_Birth']).astype('<m8[Y]').astype(int)

# %%
data.head()
# Out:
#       Id Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826 1970-01-01  Graduation       Divorced  84835.0        0         0
# 1      1 1961-01-01  Graduation         Single  57091.0        0         0
# 2  10476 1958-01-01  Graduation        Married  67267.0        0         1
# 5   7348 1958-01-01         PhD         Single  71691.0        0         0
# 6   4073 1954-01-01    2n Cycle        Married  63564.0        0         0
#
#   Dt_Customer  Recency  MntWines  ...  MntSweetProducts  MntGoldProds  \
# 0  2014-06-16        0       189  ...               189           218
# 1  2014-06-15        0       464  ...                 0            37
# 2  2014-05-13        0       134  ...                 2            30
# 5  2014-03-17        0       336  ...                32            43
# 6  2014-01-29        0       769  ...                34            65
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1311 entries, 0 to 2238
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1311 non-null   int64
#  1   Year_Birth           1311 non-null   datetime64[ns]
#  2   Education            1311 non-null   object
#  3   Marital_Status       1311 non-null   object
#  4   Income               1311 non-null   float64
#  5   Kidhome              1311 non-null   int64
#  6   Teenhome             1311 non-null   int64
#  7   Dt_Customer          1311 non-null   datetime64[ns]
#  8   Recency              1311 non-null   int64
#  9   MntWines             1311 non-null   int64
#  10  MntFruits            1311 non-null   int64
#  11  MntMeatProducts      1311 non-null   int64
#  12  MntFishProducts      1311 non-null   int64
#  13  MntSweetProducts     1311 non-null   int64
#  14  MntGoldProds         1311 non-null   int64
# ...

# %% [markdown]
# Now our dataset is clean. I have done following manipulations.
#  * I checked duplicate rows, but there are no duplicate rows in the dataset.
#  * I have successfully handled null values in the Income and Dt_customer columns by dropping rows containing null values in both the columns using dropna() method.
#  * I have also created new column 'Age' to do further analysis.
#  * I have also converted data types of columns Year_Birth and Dt_Customer from string to datetime to maintain their consistency.

# %% [markdown]
# # Summary table for numerical variable

# %%
# Calculation of Descriptive Statistics
descriptive_stats = data[['Age', 'Income', 'MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts',
                          'MntWines', 'MntGoldProds', 'NumDealsPurchases', 'NumCatalogPurchases',
                          'NumStorePurchases', 'NumWebPurchases', 'NumWebVisitsMonth', 'Recency']].describe()

# Summary Table
summary_table = descriptive_stats.transpose()[['mean', '50%', 'std', 'min', 'max']].round(2)

# Print the summary table
print(summary_table)
# Out:
#                          mean      50%       std     min       max
# Age                     44.35     43.0     12.14    17.0     121.0
# Income               51429.75  50447.0  20960.19  1730.0  157146.0
# MntFishProducts         36.47     11.0     54.47     0.0     253.0
# MntMeatProducts        162.72     66.0    219.72     0.0    1725.0
# MntFruits               25.26      7.0     38.63     0.0     197.0
# MntSweetProducts        26.92      8.0     41.04     0.0     262.0
# MntWines               302.81    171.0    339.17     0.0    1492.0
# MntGoldProds            43.87     25.0     52.09     0.0     249.0
# NumDealsPurchases        2.32      2.0      1.90     0.0      15.0
# NumCatalogPurchases      2.59      1.0      2.83     0.0      28.0
# NumStorePurchases        5.79      5.0      3.27     0.0      13.0
# NumWebPurchases          4.08      4.0      2.71     0.0      27.0
# NumWebVisitsMonth        5.41      6.0      2.43     0.0      20.0
# ...

# %% [markdown]
# # Analyzing distribution of customer demographics

# %%
# Age statistics
age_stats = data['Age'].describe().round(2)
age_stats
# Out:
# count    1311.00
# mean       44.35
# std        12.14
# min        17.00
# 25%        36.00
# 50%        43.00
# 75%        54.00
# max       121.00
# Name: Age, dtype: float64

# %%
# Education Statistics
education_counts = data['Education'].value_counts()
education_counts
# Out:
# Graduation    680
# PhD           271
# Master        220
# 2n Cycle      104
# Basic          36
# Name: Education, dtype: int64

# %%
# Marital_Status Statistics
marital_counts = data['Marital_Status'].value_counts()
marital_counts
# Out:
# Married     502
# Together    340
# Single      279
# Divorced    151
# Widow        35
# YOLO          2
# Alone         1
# Absurd        1
# Name: Marital_Status, dtype: int64

# %%
# Function showing the distribution through visualization

def analyze_demographics(data):
    # Descriptive Statistics
    age_stats = data['Age'].describe()
    education_counts = data['Education'].value_counts()
    marital_counts = data['Marital_Status'].value_counts()

    # Visualizations
    plt.figure(figsize=(12, 6))

    # Histogram for Age
    plt.subplot(2, 2, 1)
    sns.histplot(data['Age'], bins=20, kde=True)
    plt.title('Age Distribution')

    # Bar chart for Education
    plt.subplot(2, 2, 2)
    sns.countplot(x='Education', data=data)
    plt.title('Education Distribution')

    # Bar chart for Marital Status
    plt.subplot(2, 2, 3)
    sns.countplot(x='Marital_Status', data=data)
    plt.title('Marital Status Distribution')

    # Box plot for Income across Education levels
    plt.subplot(2, 2, 4)
    sns.boxplot(x='Education', y='Income', data=data)
    plt.title('Income Distribution Across Education Levels')

    plt.tight_layout()
    plt.show()

analyze_demographics(data)

# %% [markdown]
# We can draw the following observations from this visualization.
#  * The histogram depicting age distribution peaks around 40, indicating that the highest concentration falls within the age group near or slightly greater than 40. Beyond the age of 50, the distribution starts to decline.
#  * In the bar chart illustrating the distribution of education, it is evident that the majority of individuals have completed their graduation, with a count of 680. Following this, the second-highest count is for individuals holding a PhD, with a count of 271.
#  * The bar chart representing marital status reveals a predominant distribution among married individuals, totaling 502.
#  * The box plot depicting income distribution across education levels illustrates that individuals with a graduation and Ph.D. degree tend to have the highest income levels.

# %% [markdown]
# Here our first task gets completed. We have succesfully cleaned the data and also analyzed the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# # Calculating Central Tendencies - Mean, Median and Mode

# %% [markdown]
# Since there are multiple variables it is better to have a selected list of numeric variables for calculating the central tendencies and dispersion.

# %%
# 1. Mean

def calculate_mean(data, selected_columns):
    # Calculate mean
    mean_values = data[selected_columns].mean()

    result_data = pd.DataFrame({
        'Category': selected_columns,
        'Mean': mean_values.values,
        })

    return result_data

# Selected list
selected_list = ['Age', 'Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts','MntSweetProducts', 'NumDealsPurchases', 'MntGoldProds',
                 'NumWebPurchases', 'NumCatalogPurchases','NumStorePurchases','NumWebVisitsMonth']

result_data = calculate_mean(data, selected_list)

# Display the result
print(result_data.to_string(index=False))
# Out:
#            Category         Mean
#                 Age    44.349352
#              Income 51429.747521
#             Recency    49.302059
#            MntWines   302.807018
#           MntFruits    25.255530
#     MntMeatProducts   162.717010
#     MntFishProducts    36.471396
#    MntSweetProducts    26.922960
#   NumDealsPurchases     2.317315
#        MntGoldProds    43.874905
#     NumWebPurchases     4.081617
# NumCatalogPurchases     2.594966
#   NumStorePurchases     5.794050
#   NumWebVisitsMonth     5.410374

# %%
# 2. Median

def calculate_median(data, selected_columns):
    # Calculate median
    median_values = data[selected_columns].median()

    result_data = pd.DataFrame({
        'Category': selected_columns,
        'Median': median_values.values,
        })

    return result_data

# Selected list
selected_list = ['Age', 'Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts','MntSweetProducts', 'NumDealsPurchases', 'MntGoldProds',
                 'NumWebPurchases', 'NumCatalogPurchases','NumStorePurchases','NumWebVisitsMonth']

result_data = calculate_median(data, selected_list)

# Display the result
print(result_data.to_string(index=False))
# Out:
#            Category  Median
#                 Age    43.0
#              Income 50447.0
#             Recency    50.0
#            MntWines   171.0
#           MntFruits     7.0
#     MntMeatProducts    66.0
#     MntFishProducts    11.0
#    MntSweetProducts     8.0
#   NumDealsPurchases     2.0
#        MntGoldProds    25.0
#     NumWebPurchases     4.0
# NumCatalogPurchases     1.0
#   NumStorePurchases     5.0
#   NumWebVisitsMonth     6.0

# %%
# 3. Mode

def calculate_modes(data, selected_columns):
    modes = {}

    for variable in selected_columns:
        modes[variable] = data[variable].mode().values[0]

    return pd.Series(modes)

selected_list = ['Complain', 'Response', 'Income', 'Age', 'Kidhome', 'Teenhome', 'MntWines', 'NumWebVisitsMonth', 'Education', 'Marital_Status']

result_modes = calculate_modes(data, selected_list)
print(f'Mode of selected columns in the dataset are:\n{result_modes}')
# Out:
# Mode of selected columns in the dataset are:
# Complain                      0
# Response                      0
# Income                   7500.0
# Age                          41
# Kidhome                       0
# Teenhome                      0
# MntWines                      2
# NumWebVisitsMonth             7
# Education            Graduation
# Marital_Status          Married
# dtype: object

# %% [markdown]
# # Measures of Dispersion - Variance and Standard Deviation

# %%
# 1. Variance

def calculate_variance(data, selected_columns):
    # Calculate variance
    variance_values = data[selected_columns].var()

    result_data = pd.DataFrame({
        'Category': selected_columns,
        'Variance': variance_values.values,
        })

    return result_data

# Selected list
selected_list = ['Age', 'Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
                 'NumDealsPurchases', 'MntGoldProds', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']

result_data = calculate_variance(data, selected_list)

# Display the result
print(result_data.to_string(index=False))
# Out:
#            Category     Variance
#                 Age 1.474504e+02
#              Income 4.393294e+08
#             Recency 8.295881e+02
#            MntWines 1.150355e+05
#           MntFruits 1.492012e+03
#     MntMeatProducts 4.827584e+04
#     MntFishProducts 2.966953e+03
#    MntSweetProducts 1.684491e+03
#   NumDealsPurchases 3.599998e+00
#        MntGoldProds 2.713658e+03
#     NumWebPurchases 7.340662e+00
# NumCatalogPurchases 8.028952e+00
#   NumStorePurchases 1.069038e+01
#   NumWebVisitsMonth 5.921541e+00

# %%
# 2. Standard Deviation

def calculate_std(data, selected_columns):
    # Calculate standard deviation
    std_values = data[selected_columns].std()

    result_data = pd.DataFrame({
        'Category': selected_columns,
        'Standard_Deviation': std_values.values,
    })

    return result_data


selected_list = ['Age', 'Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
                 'NumDealsPurchases', 'MntGoldProds', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']

result_data = calculate_std(data, selected_list)

# Display the result
print(result_data.to_string(index=False))
# Out:
#            Category  Standard_Deviation
#                 Age           12.142915
#              Income        20960.186407
#             Recency           28.802571
#            MntWines          339.168809
#           MntFruits           38.626568
#     MntMeatProducts          219.717636
#     MntFishProducts           54.469746
#    MntSweetProducts           41.042551
#   NumDealsPurchases            1.897366
#        MntGoldProds           52.092779
#     NumWebPurchases            2.709366
# NumCatalogPurchases            2.833540
#   NumStorePurchases            3.269614
#   NumWebVisitsMonth            2.433422

# %% [markdown]
# # Handling Outliers Using Boxplot

# %%
# We will plot a box plot to detect outliers

def plot_boxplots(data, key_variables):
    # Set the number of rows and columns for subplots
    num_rows = (len(key_variables) + 2) // 3
    num_cols = 3

    # Create subplots
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5*num_rows))
    fig.suptitle('Boxplots for Key Variables')

    # Flatten the axes array
    axes = axes.flatten()

    # Plot each numeric variable in a separate subplot
    for i, variable in enumerate(key_variables):
        sns.boxplot(x=data[variable], ax=axes[i])
        axes[i].set_title(variable)

    # Adjust layout
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

    # Display the subplots
    plt.show()

key_variables = ['Income', 'Age', 'MntWines', 'MntFruits', 'MntMeatProducts', 'Recency']

plot_boxplots(data, key_variables)

# %% [markdown]
# ###There are outliers present in various columns in our dataset, so we will remove those by IQR method.

# %%
# Using IQR Method

# Function to remove outliers
def remove_outliers(data, columns):

    for column in columns:
        Q1 = data[column].quantile(0.20)
        Q3 = data[column].quantile(0.80)
        IQR = Q3 - Q1

        # Define the upper and lower bounds for outlier removal
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Remove outliers
        data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

    return data

columns_with_outliers = ['Income', 'Age', 'MntWines', 'MntFruits', 'MntMeatProducts']

# Remove outliers from specified columns
df_new = remove_outliers(data, columns_with_outliers)

# %% [markdown]
# ####We will now check if outliers are cleaned or not.

# %%
# Function to check outliers cleaned or not
def plot_boxplots_comparison(data, key_variables, cleaned_data):
    # Create subplots with transposed layout
    fig, axes = plt.subplots(nrows=len(key_variables), ncols=2, figsize=(12, 7))

    # Plot box plots for each variable
    for i, variable in enumerate(key_variables):
        sns.boxplot(x=variable, data=data, ax=axes[i, 0])
        axes[i, 0].set_title(f'Boxplot of {variable} (Original)')

        sns.boxplot(x=variable, data=df_new, ax=axes[i, 1])
        axes[i, 1].set_title(f'Boxplot of {variable} (Cleaned)')

    plt.tight_layout()
    plt.show()

key_variables = ['Income', 'Age']

plot_boxplots_comparison(data, key_variables, df_new)

# %% [markdown]
# ####We can see that almost all the outliers are removed.

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
#  ## Let's first plot the distribution of variables which follows normal or close to normal distribution.

# %%
# Function to calculate normal distribution
def plot_distribution_curves(data, key_variables):
    # Calculate the number of rows and columns for subplots
    num_rows = (len(key_variables) + 1) // 2
    num_cols = min(2, len(key_variables))

    # Create subplots
    fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 5*num_rows))
    fig.suptitle('Distribution Curves for Key Variables', y=1.02)

    # Flatten axes for easy indexing
    axes = axes.flatten()

    # Plot distribution curves for each variable
    for i, variable in enumerate(key_variables):
        sns.histplot(data[variable], kde=True, ax=axes[i])
        axes[i].set_title(f'Distribution of {variable}')

    # Remove empty subplots
    for i in range(len(key_variables), len(axes)):
        fig.delaxes(axes[i])

    plt.tight_layout()
    plt.show()

key_variables = ['Income', 'Age', 'Recency']
plot_distribution_curves(df_new, key_variables)

# %% [markdown]
# ## Probability and expected value calculation for normal distribution

# %%
# 1. Let's calculate first for Income :

import numpy as np
from scipy.stats import norm

def calculate_probabilities_and_expectation(data, variable, threshold1, threshold2):
    # Calculate mean and standard deviation
    mean_val = np.mean(data[variable])
    std_dev_val = np.std(data[variable])

    # Calculate probabilities
    prob_less_than_threshold1 = norm.cdf(threshold1, loc=mean_val, scale=std_dev_val)
    prob_greater_than_threshold2 = 1 - norm.cdf(threshold2, loc=mean_val, scale=std_dev_val)

    # Calculate expected value (mean)
    expected_val = mean_val

    # Print results
    print(f"Variable: {variable}")
    print(f"Probability of {variable} less than {threshold1:.2f}: {prob_less_than_threshold1:.4f}")
    print(f"Probability of {variable} greater than {threshold2:.2f}: {prob_greater_than_threshold2:.4f}")
    print(f"Expected {variable}: {expected_val:.2f}\n")

calculate_probabilities_and_expectation(df_new, 'Income', 70000, 80000)
# Out:
# Variable: Income
# Probability of Income less than 70000.00: 0.8828
# Probability of Income greater than 80000.00: 0.0429
# Expected Income: 47529.71

# %%
# 2. Let's calculate for Age

import numpy as np
from scipy.stats import norm

def calculate_probabilities_and_expectation_age(data, threshold1, threshold2):
    # Calculate mean and standard deviation for 'Age'
    mean_age = np.mean(data['Age'])
    std_dev_age = np.std(data['Age'])

    # Calculate probabilities
    prob_less_than_threshold1 = norm.cdf(threshold1, loc=mean_age, scale=std_dev_age)
    prob_greater_than_threshold2 = 1 - norm.cdf(threshold2, loc=mean_age, scale=std_dev_age)

    # Calculate expected value (mean)
    expected_age = mean_age

    # Print results
    print("Variable: Age")
    print(f"Probability of age less than {threshold1}: {prob_less_than_threshold1:.2f}")
    print(f"Probability of age greater than {threshold2}: {prob_greater_than_threshold2:.2f}")
    print(f"Expected age: {expected_age:.2f}\n")

calculate_probabilities_and_expectation_age(df_new, 30, 40)
# Out:
# Variable: Age
# Probability of age less than 30: 0.11
# Probability of age greater than 40: 0.64
# Expected age: 44.13

# %%
# 3. Let's calculate for Recency (No. of days since last purchase made)
import numpy as np
from scipy.stats import norm

def calculate_probabilities_and_expectation_recency(data, threshold1, threshold2):
    # Calculate mean and standard deviation for 'Recency'
    mean_recency = np.mean(data['Recency'])
    std_dev_recency = np.std(data['Recency'])

    # Calculate probabilities
    prob_less_than_threshold1 = norm.cdf(threshold1, loc=mean_recency, scale=std_dev_recency)
    prob_greater_than_threshold2 = 1 - norm.cdf(threshold2, loc=mean_recency, scale=std_dev_recency)

    # Calculate expected value (mean)
    expected_recency = mean_recency

    # Print results
    print("Variable: Recency")
    print(f"Probability of recency less than {threshold1}: {prob_less_than_threshold1:.4f}")
    print(f"Probability of recency greater than {threshold2}: {prob_greater_than_threshold2:.4f}")
    print(f"Expected recency: {expected_recency:.2f}\n")

calculate_probabilities_and_expectation_recency(df_new, 10, 15)
# Out:
# Variable: Recency
# Probability of recency less than 10: 0.0876
# Probability of recency greater than 15: 0.8814
# Expected recency: 48.95

# %% [markdown]
# ## Let's plot the distribution of variables which follows binomial distribution.

# %%
# Function to plot binomial distribution curve

def plot_binomial_distribution_curves(data, key_variables):
    # Calculate the number of rows and columns for subplots
    num_rows = (len(key_variables) + 1) // 2
    num_cols = min(2, len(key_variables))

    # Create subplots
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
    fig.suptitle('Distribution Curves for Key Variables which follow Binomial Distribution', y=1.02)

    # Flatten axes for easy indexing
    axes = axes.flatten()

    # Plot distribution curves for each variable
    for i, variable in enumerate(key_variables):
        sns.histplot(data[variable], kde=True, ax=axes[i])
        axes[i].set_title(f'Distribution of {variable}')

    # Remove empty subplots
    for i in range(len(key_variables), len(axes)):
        fig.delaxes(axes[i])

    plt.tight_layout()
    plt.show()

key_variables_binomial = ['Response', 'Complain']
plot_binomial_distribution_curves(df_new, key_variables_binomial)

# %% [markdown]
# ## Probability and expected value calculation for binomial distribution

# %%
# Let's calculate probability and expected values for Response (if customer accepted the offer in the last campaign or not )
# and for Complain (complains made in last 2 years) variable

from scipy.stats import binom

def calculate_probabilities_and_expectation_binomial(data, variable):
    # Number of trials
    n_trials = len(data[variable])

    # Probability of success
    p_success = np.mean(data[variable])

    # Number of successes
    k_success = np.sum(data[variable] == 1)

    # Calculate probabilities using the PMF
    prob_success_1 = binom.pmf(k_success, n_trials, p_success)

    # Calculate expected value (mean)
    expected_value = n_trials * p_success

    # Print results
    print(f"Variable: {variable}")
    print(f"Probability of {variable} being 1: {prob_success_1:.4f}")
    print(f"Expected value for {variable}: {expected_value:.2f}\n")

calculate_probabilities_and_expectation_binomial(df_new, 'Response')
calculate_probabilities_and_expectation_binomial(df_new, 'Complain')
# Out:
# Variable: Response
# Probability of Response being 1: 0.0353
# Expected value for Response: 146.00
#
# Variable: Complain
# Probability of Complain being 1: 0.1323
# Expected value for Complain: 9.00

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# ## 1. Scatter plot for showing distribution of Income vs. Spending Habits

# %%
# Scatter plot using matplotlib
def scatter_plot_income_vs_spending(df, income_column, spending_columns):

    plt.figure(figsize=(12, 8))

    for spending_column in spending_columns:
        plt.scatter(df[income_column], df[spending_column], label=spending_column)

    plt.title('Income vs Spending Habits')
    plt.xlabel('Income')
    plt.ylabel('Spending Amount')
    plt.legend()
    plt.show()

spending_columns = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']

scatter_plot_income_vs_spending(df_new, 'Income', spending_columns)

# %% [markdown]
# **Insight:** Through this chart we are able to see that as income increases people are more likely to purchase wines and after that comes the meat products, while all the other categories are having somewhat constant distribution related with income and spending habits.

# %% [markdown]
# ## 2. Grouped bar chart showing distribution of 'Education' and 'Marital_Status'

# %%
# Function to plot grouped bar chart

def plot_education_marital_distribution(df, education_column, marital_column):

    plt.figure(figsize=(10, 6))
    sns.countplot(x=education_column, data=df, hue=marital_column, palette='Dark2')
    plt.title('Education and Marital Status Distribution')
    plt.xlabel('Education')
    plt.ylabel('Count')
    plt.show()


plot_education_marital_distribution(df_new, 'Education', 'Marital_Status')

# %% [markdown]
# **Insight:** Through this grouped bar chart we are able to see that most of the customers have done their graduation, in that also married and together count is high as compared to other marital_status. While on the other hand there are very few customers who have less count of basic education.

# %% [markdown]
# ## 3. Scatter plot showing distribution of Age vs. Spending habits

# %%
# Function to plot scatter plot
def scatter_plot_age_vs_spending(df, age_column, spending_columns):

    plt.figure(figsize=(12, 8))

    for spending_column in spending_columns:
        plt.scatter(df[age_column], df[spending_column], label=spending_column)

    plt.title('Age vs Spending Habits')
    plt.xlabel('Age')
    plt.ylabel('Spending Amount')
    plt.legend()
    plt.show()

spending_columns = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
scatter_plot_age_vs_spending(df_new, 'Age', spending_columns)

# %% [markdown]
# **Insight:** Through this scatter plot we are able to see that almost all the age group has the highest spending amount for the wines and then comes the meat products.

# %% [markdown]
# ## 4. Correlation heatmap to show relationship between different variables

# %%
# Function to plot correlation heatmap
def plot_correlation_heatmap(df, numerical_columns):

    # Selecting numerical columns for correlation heatmap
    numerical_data = df[numerical_columns]

    # Calculate the correlation matrix
    correlation_matrix = numerical_data.corr()

    # Plot the heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt=".2f", linewidths=.5)
    plt.title('Correlation Heatmap of Numerical Variables')
    plt.show()

numerical_columns_to_plot = ['Age', 'Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts',
                             'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
                             'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
                             'NumStorePurchases', 'NumWebVisitsMonth']

plot_correlation_heatmap(df_new, numerical_columns_to_plot)

# %% [markdown]
# # Customer Segmentation

# %% [markdown]
# ### 1. Let's segment customers based on their spending habits

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Selecting relevant columns for clustering
selected_columns = ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']

# Creating a new DataFrame with selected columns
X = df_new[selected_columns]

# Standardizing the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Choosing the number of clusters (you may adjust this based on your analysis)
num_clusters = 3

# Applying K-means clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df_new['Cluster'] = kmeans.fit_predict(X_scaled)

# Visualizing the clusters (considering two dimensions only for simplicity)
plt.scatter(df_new['MntWines'], df_new['MntMeatProducts'], c=df_new['Cluster'], cmap='viridis')
plt.xlabel('Spending on Wines')
plt.ylabel('Spending on Meat Products')
plt.title('Customer Segmentation based on Spending Behavior')
plt.show()

# Displaying the average spending for each cluster
cluster_avg_spending = df_new.groupby('Cluster')[selected_columns].mean()
print(cluster_avg_spending)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#            MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# Cluster
# 0        573.382979  21.060284       174.471631        31.776596
# 1         72.919831   5.070323        29.414909         7.534459
# 2        533.510067  53.033557       330.805369       110.543624
#
#          MntSweetProducts  MntGoldProds
# Cluster
# 0               23.446809     69.503546
# 1                5.358650     16.563994
# 2               85.248322     84.765101

# %% [markdown]
# #### We can see that there is a big cluster of high spending on wines as compared to spending on meat products.

# %% [markdown]
# ##2. Let's now segment customers based on total spending and income of customers.

# %%
from sklearn.cluster import KMeans

def elbow_method_graph(df, variables, max_clusters=10):

    # Creating a new column TotalSpending for clustering
    df['TotalSpending'] = df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].sum(axis=1)

    # Applying k-means with different number of clusters
    inertia = []  # List to store the inertia for each k
    for k in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=k, random_state=0).fit(df[variables])
        inertia.append(kmeans.inertia_)

    # Plotting the Elbow Method Graph
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, max_clusters + 1), inertia, marker='o')
    plt.title("Elbow Method")
    plt.xlabel("Number of clusters")
    plt.ylabel("Inertia")
    plt.xticks(range(1, max_clusters + 1))
    plt.show()

key_variables_to_cluster = ['Income', 'TotalSpending']
elbow_method_graph(df_new, key_variables_to_cluster)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ### From above plot we can see that optimal number of clusters should be 3

# %%
# Function to plot clusters based on Income vs TotalSpending
def kmeans_clustering_and_visualization(df, features_for_clustering, num_clusters=3):

    # Fit KMeans model
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    df['Cluster1'] = kmeans.fit_predict(df[features_for_clustering])

    # Visualize the clusters based on 'TotalSpending' and 'Income'
    plt.figure(figsize=(12, 6))
    plt.scatter(df[df['Cluster1'] == 0]['Income'], df[df['Cluster1'] == 0]['TotalSpending'], s=80, c='red', label='Low Income, Low Spenders')
    plt.scatter(df[df['Cluster1'] == 1]['Income'], df[df['Cluster1'] == 1]['TotalSpending'], s=80, c='blue', label='Medium Income, Moderate Spenders')
    plt.scatter(df[df['Cluster1'] == 2]['Income'], df[df['Cluster1'] == 2]['TotalSpending'], s=80, c='green', label='High Income, High Spenders')

    plt.title('Clusters of Customers based on Total Spending vs Income')
    plt.xlabel('Annual Income')
    plt.ylabel('Total Spending')
    plt.legend()
    plt.show()

features_for_clustering = ['Income', 'TotalSpending']
kmeans_clustering_and_visualization(df_new, features_for_clustering)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Here we can observe that a majority of customers are of high income and high spenders, followed by low income and low spending habits.

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# #### We will create new columns Month and Day from Dt_Customer for time series analysis.

# %%
df_new['month'] = df_new['Dt_Customer'].dt.strftime('%B')

# %%
df_new['day'] =  df_new['Dt_Customer'].dt.strftime('%A')

# %% [markdown]
# # Visualization

# %% [markdown]
# ### 1. Line chart showing trends of visitors across the month on website

# %%
# Function to plot line chart
def plot_website_visitors_trends(df, month_column, visits_column):

    # Set the month column as categorical with custom order
    months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    df[month_column] = pd.Categorical(df[month_column], categories=months, ordered=True)

    # Plotting the trends of visitors across the month on the website
    plt.figure(figsize=(15, 10))
    sns.lineplot(x=month_column, y=visits_column, data=df.groupby(month_column)[visits_column].sum().reset_index(), color='green')
    plt.title("Trends of Visitors Across the Month on Website")
    plt.xticks(rotation=45)
    plt.show()

plot_website_visitors_trends(df_new, 'month', 'NumWebVisitsMonth')

# %% [markdown]
# **Insight:** Through this line chart we can see that in the August month the number of visitors are very high, while July month is having less number of visitors. So this chart is helpful for the Superstore mangement to take necessary actions so that they can improve number of visitors in the months where count is less.

# %% [markdown]
# ### 2.  Bar chart for showing number of purchases made through website per month

# %%
# Function to plot bar chart
def plot_monthly_website_purchases(df, month_column, purchases_column):

    plt.figure(figsize=(14, 5))
    sns.barplot(x=month_column, y=purchases_column, data=df.groupby(month_column)[purchases_column].sum().reset_index(), palette='Dark2')
    plt.title('Number of Purchases (Website) - Monthly')
    plt.show()

plot_monthly_website_purchases(df_new, 'month', 'NumWebPurchases')
# Out:
# <ipython-input-113-d2226e62ba65>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=month_column, y=purchases_column, data=df.groupby(month_column)[purchases_column].sum().reset_index(), palette='Dark2')

# %% [markdown]
# **Insight:** Through this bar chart we can see that number of purchases through the website are high in the month of August, while they are less in the month of July. So this chart is helpful for the management to find out the solution so that they can improve website purchases.

# %% [markdown]
# ###3. Line chart for showing number of purchases made through website per day

# %%
# Function to plot line chart
def plot_daily_website_purchases(df, day_column, purchases_column, day_order):

    # Convert 'day' to a categorical variable with a specified order
    df[day_column] = pd.Categorical(df[day_column], categories=day_order, ordered=True)

    plt.figure(figsize=(12, 5))
    plt.plot(day_column, purchases_column, data=df.groupby(day_column)[purchases_column].sum().reset_index())
    plt.title('Number of Purchases (Website) - Daily')
    plt.show()

day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
plot_daily_website_purchases(df_new, 'day', 'NumWebPurchases', day_order)

# %% [markdown]
# **Insight:** Through this line chart we can see that highest number of purchases were made on Wednesday while least number of purchases were made on Thursday. This chart is helpful for the management to give certain schemes or discounts to attract more customers on particular day.

# %% [markdown]
# ###4. Scatter plot to visualize relationship between Income and Total Spending based on Marital Status

# %%
# Function to plot scatter plot
def scatter_plot_income_vs_spending_by_marital_status(df, income_column, spending_column, marital_status_column):

    plt.figure(figsize=(12, 5))
    sns.scatterplot(x=income_column, y=spending_column, hue=marital_status_column, data=df)
    plt.title('Scatter Plot of Income vs Total Spending')
    plt.show()

scatter_plot_income_vs_spending_by_marital_status(df_new, 'Income', 'TotalSpending', 'Marital_Status')

# %% [markdown]
# **Insight:** Through this chart we can see that income is positively correlated with total spending for all the categories in the marital_status.

# %% [markdown]
# ###5. Scatter plot to visualize relationship between Income and Total Spending based on Age

# %%
# Function to plot scatter plot
def scatter_plot_income_vs_spending_by_age(df, income_column, total_spending_column, age_column):

    # Calculate total spending
    df['Total_Spending'] = df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].sum(axis=1)

    # Scatter plot
    plt.figure(figsize=(12, 6))
    sns.scatterplot(x=income_column, y=total_spending_column, hue=age_column, data=df, palette='viridis', size=age_column, sizes=(30, 200))
    plt.title('Relationship between Income and Total Spending based on Age')
    plt.xlabel('Income')
    plt.ylabel('Total Spending')
    plt.legend(title='Age')
    plt.show()

scatter_plot_income_vs_spending_by_age(df_new, 'Income', 'Total_Spending', 'Age')

# %% [markdown]
# **Insight:** Through this scatter plot we are able to see that for age group after 40 are likely to spend higher. So to attract these customers this chart is helpful to plan accordingly.

# %% [markdown]
# ###6. Pie chart to show the distribution of Complain and Response

# %%
# Function to plot pie chart

def plot_complain_and_response_distribution(df, complain_column, response_column):

   # Calculate counts for each category
    complain_counts = df[complain_column].value_counts()
    response_counts = df[response_column].value_counts()

    # Plotting a pie chart for Complain
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.pie(complain_counts, labels=complain_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'])
    plt.title('Distribution of Complain')

    # Plotting a pie chart for Response
    plt.subplot(1, 2, 2)
    plt.pie(response_counts, labels=response_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'])
    plt.title('Distribution of Response')

    plt.tight_layout()
    plt.show()

plot_complain_and_response_distribution(df_new, 'Complain', 'Response')

# %% [markdown]
# **Insight:** We are able to see through this pie chart that distribution of complains given by customers is only 0.8%, while the percent of response is 12.8%. This indicates that there is satisfactory customer experiences and potential areas for improvement in engagement strategies.

# %% [markdown]
# ##  Conclusion and Recommendations

# %% [markdown]
# 1. **Suggestion based on Statistical Analysis:**
#
#
# *   With an expected income (mean) of 47,529 falling in the mid-range, the marketing team is advised to promote mid-range products more frequently to this customer segment.
#
#
# *   The anticipated customer age is 44 years, emphasizing the need to target the 40-50 age group for increased engagement and purchases.
#
#
# *   The expected recency is 48.95, and only 8% of customers are likely to make a purchase within 10 days. To encourage more frequent transactions, the company should offer discounts and promotions to attract and activate these customers.
#
#
#
#
#
# 2. **Recommendation Based on EDA and segmentation**
#
#
# *   Customers displaying high spending on wines also exhibit a preference for meat products. The company should consider offering complementary deals and cross-selling strategies to capitalize on these correlated purchases, potentially increasing overall profitability.
#
# *   The dataset indicates a prominent segmentation of customers into two main groups: those with high income and high spending habits, and those with low income and low spending. To maximize returns, the marketing team can target the high-income segment with luxury brand offers, while employing different strategies for other customer groups.
#
# *   August sees the highest customer visits and purchases on the website, while July records the lowest. To boost sales during the low-performing month, the company should deploy additional marketing efforts, such as promotional offers, ads, and targeted emails.
#
# *   Married or cohabiting customers exhibit a higher likelihood of increased spending. To leverage this trend, the company is advised to introduce targeted offers and initiate programs specifically designed for couples, aiming to monetize and capitalize on these customer behaviors.
